# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
file = "CPdescarga.xlsx"

# %%
engine = create_engine("sqlite:///./database.db")
df = pd.read_excel(file, sheet_name="Aguascalientes")
#df.to_sql("colonias", engine, if_exist="replace", index=False)
df
# Out:
#       d_codigo                 d_asenta    d_tipo_asenta         D_mnpio  \
# 0        20000    Aguascalientes Centro          Colonia  Aguascalientes
# 1        20010          Colinas del Rio  Fraccionamiento  Aguascalientes
# 2        20010         Olivares Santana          Colonia  Aguascalientes
# 3        20010               Las Brisas  Fraccionamiento  Aguascalientes
# 4        20010        Ramon Romo Franco  Fraccionamiento  Aguascalientes
# ...        ...                      ...              ...             ...
# 1359     20996             Los Arquitos            Ejido     Jesús María
# 1360     20996             La Primavera          Colonia     Jesús María
# 1361     20997                El Chacho           Pueblo     Jesús María
# 1362     20997                 Ruscello       Condominio     Jesús María
# 1363     20997  Q Campestre Residencial       Condominio     Jesús María
#
#             d_estado        d_ciudad   d_CP  c_estado  c_oficina  c_CP  \
# ...

# %%
xl = pd.ExcelFile(file)
lista = xl.sheet_names  # see all sheet names
lista
#xl.parse(sheet_name)  # read a specific sheet to DataFrame
# Out:
# ['Nota',
#  'Aguascalientes',
#  'Baja_California',
#  'Baja_California_Sur',
#  'Campeche',
#  'Coahuila_de_Zaragoza',
#  'Colima',
#  'Chiapas',
#  'Chihuahua',
#  'Distrito_Federal',
#  'Durango',
#  'Guanajuato',
#  'Guerrero',
#  'Hidalgo',
#  'Jalisco',
#  'México',
#  'Michoacán_de_Ocampo',
#  'Morelos',
#  'Nayarit',
#  'Nuevo_León',
#  'Oaxaca',
#  'Puebla',
#  'Querétaro',
#  'Quintana_Roo',
#  'San_Luis_Potosí',
#  'Sinaloa',
#  'Sonora',
#  'Tabasco',
#  'Tamaulipas',
#  'Tlaxcala',
#  'Veracruz_de_Ignacio_de_la_Llave',
#  'Yucatán',
#  'Zacatecas']

# %%
engine.execute("CREATE TABLE IF NOT EXISTS colonias ({})".format(" ,".join(df.columns)))

# %%
# for row in df.iterrows():
#     sql = "INSERT INTO colonias ({}) VALUES ({})".format(" ,".join(df.columns), ",".join(["?"]*len(df.columns)))
#     engine.execute(sql, tuple(row[1]))

# %%
# añadir todos los sheet de un archivo excel a una base de datos
# for sheet in range(1, len(lista)):
#     df = pd.read_excel(file, sheet_name=lista[sheet])
#     for row in df.iterrows():
#         sql = "INSERT INTO colonias ({}) VALUES ({})".format(" ,".join(df.columns), ",".join(["?"]*len(df.columns)))
#         engine.execute(sql, tuple(row[1]))
